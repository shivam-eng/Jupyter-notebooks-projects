# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('example.csv', delimiter = ',')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-28dac053f4a4> in <module>
# ----> 1 df = pd.read_csv('example.csv', delimiter = ',')
#       2 df
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pd.read_csv('example.csv', delimiter = ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b407b1640b71> in <module>
# ----> 1 pd.read_csv('example.csv', delimiter = ',')
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('animal.csv',delimiter = ',')
df
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
df.to_csv('animal_output.csv',index = False)

# %%
import numpy as np
import pandas as pd

# %%
labels = ['StudentID','Rank','Age']
my_list = [101,5,21]
arr = np.array([101,5,21])
d = {'StudentID':101,'Rank':5,'Age':21}

# %%
pd.Series(data=my_list)
# Out:
# 0    101
# 1      5
# 2     21
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# StudentID    101
# Rank           5
# Age           21
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# StudentID    101
# Rank           5
# Age           21
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    101
# 1      5
# 2     21
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# StudentID    101
# Rank           5
# Age           21
# dtype: int64

# %%
pd.Series(d)
# Out:
# StudentID    101
# Rank           5
# Age           21
# dtype: int64

# %%
pd.Series(data=labels)
# Out:
# 0    StudentID
# 1         Rank
# 2          Age
# dtype: object

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index = ['Bangalore', 'Mumbai', 'Delhi', 'Gurgaon'])

# %%
ser1
# Out:
# Bangalore    1
# Mumbai       2
# Delhi        3
# Gurgaon      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['Bangalore', 'Mumbai', 'Hyderabad', 'Gurgaon'])

# %%
ser2
# Out:
# Bangalore    1
# Mumbai       2
# Hyderabad    5
# Gurgaon      4
# dtype: int64

# %%
ser1['Mumbai']
# Out:
# 2

# %%
ser1 + ser2
# Out:
# Bangalore    2.0
# Delhi        NaN
# Gurgaon      8.0
# Hyderabad    NaN
# Mumbai       4.0
# dtype: float64

# %%
import pandas as pd

# %%
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.read_excel('WiDS_data_dictionary_v2.xlsx')

# %%
df
# Out:
#      Column Name                                           Question  \
# 0      is_female         DG2. Is the respondent a male or a female?
# 1            AA3                                          AA3. Zone
# 2            AA5                                    AA5. Town Class
# 3            AA6                                 AA6. Village Class
# 4            AA8                                AA8. Town Selection
# 5           AA19                                  AA19. Accompanied
# 6           AA20                                 AA20. Back Checked
# 7           AA21                                  AA21. Scrutinized
# 8            AB3                            AB3. Interviewer Gender
# 9            AB6                              AB6. Day of interview
# 10           DG3                  DG3. What is your marital status?
# 11          DG3A                             What is your religion?
# 12           DG4      DG4. What is your highest level of education?
# ...

# %%
df.set_index('Column Name', inplace = True)
df
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df['Question']
# Out:
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# DG5_2        DG5.2.Do you have any of the following type of...
# ...

# %%
df[['Question','Values']]
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df.loc['is_female']
# Out:
# Question    DG2. Is the respondent a male or a female?
# Values                                1=Male\n2=Female
# Name: is_female, dtype: object

# %%
type(df['Question'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc['is_female'])
# Out:
# pandas.core.series.Series

# %%
df['Q & A'] = df['Question'] + df['Values']

# %%
df
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df.drop('Q & A', axis = 1)
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df.drop('Q & A',axis = 1,inplace = True)

# %%
df
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df.drop('is_female',axis = 0)
# Out:
#                                                       Question  \
# Column Name
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# DG5_2        DG5.2.Do you have any of the following type of...
# ...

# %%
df.iloc[2]
# Out:
# Question                                      AA5. Town Class
# Values      1=Town Class 1\n2=Town Class 2\n3=Town Class 3...
# Name: AA5, dtype: object

# %%
df.loc['RI5_1','Values']
# Out:
# 'N/A\n99=DK'

# %%
df.loc[['RI5_2','RI5_2'],['Question','Values']]
# Out:
#                                                       Question      Values
# Column Name
# RI5_2        RI5.2.Can you give me all the mobile phone num...  N/A\n99=DK
# RI5_2        RI5.2.Can you give me all the mobile phone num...  N/A\n99=DK

# %%
df
# Out:
#                                                       Question  \
# Column Name
# is_female           DG2. Is the respondent a male or a female?
# AA3                                                  AA3. Zone
# AA5                                            AA5. Town Class
# AA6                                         AA6. Village Class
# AA8                                        AA8. Town Selection
# AA19                                         AA19. Accompanied
# AA20                                        AA20. Back Checked
# AA21                                         AA21. Scrutinized
# AB3                                    AB3. Interviewer Gender
# AB6                                      AB6. Day of interview
# DG3                          DG3. What is your marital status?
# DG3A                                    What is your religion?
# DG4              DG4. What is your highest level of education?
# DG5_1        DG5.1.Do you have any of the following type of...
# ...

# %%
df.reset_index()
# Out:
#      Column Name                                           Question  \
# 0      is_female         DG2. Is the respondent a male or a female?
# 1            AA3                                          AA3. Zone
# 2            AA5                                    AA5. Town Class
# 3            AA6                                 AA6. Village Class
# 4            AA8                                AA8. Town Selection
# 5           AA19                                  AA19. Accompanied
# 6           AA20                                 AA20. Back Checked
# 7           AA21                                  AA21. Scrutinized
# 8            AB3                            AB3. Interviewer Gender
# 9            AB6                              AB6. Day of interview
# 10           DG3                  DG3. What is your marital status?
# 11          DG3A                             What is your religion?
# 12           DG4      DG4. What is your highest level of education?
# ...

# %%
import numpy as np
import pandas as pd

# %%
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df = pd.DataFrame(np.random.randn(6,2),index = hier_index,columns = ['A','B'])
df
# Out:
#              A         B
# G1 1  0.255759  1.531937
#    2  2.232175 -0.835001
#    3  2.279166 -0.733505
# G2 1  0.809726 -0.819149
#    2  0.998819 -0.388797
#    3 -0.021157 -0.759493

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.255759  1.531937
# 2  2.232175 -0.835001
# 3  2.279166 -0.733505

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.255759
# B    1.531937
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    0.255759  1.531937
#       2    2.232175 -0.835001
#       3    2.279166 -0.733505
# G2    1    0.809726 -0.819149
#       2    0.998819 -0.388797
#       3   -0.021157 -0.759493

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.255759  1.531937
# 2    2.232175 -0.835001
# 3    2.279166 -0.733505

# %%
df.xs(['G1',1])
# Out:
# A    0.255759
# B    1.531937
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1     0.255759  1.531937
# G2     0.809726 -0.819149
